# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting deepcell==0.12.10
#   Downloading DeepCell-0.12.10.tar.gz (148 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.3/148.3 kB 23.0 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: pip in /root/venv/lib/python3.10/site-packages (from -r ./requirements.txt (line 3)) (23.0.1)
# Collecting scipy<2,>=1.2.3
#   Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 63.9 MB/s eta 0:00:00
# Collecting matplotlib
#   Downloading matplotlib-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 131.3 MB/s eta 0:00:00
# Collecting jupyter<2,>=1.0.0
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Collecting opencv-python-headless<5
#   Downloading opencv_python_headless-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (50.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 MB 52.4 MB/s eta 0:00:00
# Collecting spektral~=1.0.4
#   Downloading spektral-1.0.8-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 40.2 MB/s eta 0:00:00
# Collecting tensorflow_addons~=0.16.1
#   Downloading tensorflow_addons-0.16.1-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 117.4 MB/s eta 0:00:00
# Collecting tqdm
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 27.7 MB/s eta 0:00:00
# Collecting tensorflow~=2.8.0
#   Downloading tensorflow-2.8.4-cp310-cp310-manylinux2010_x86_64.whl (498.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.1/498.1 MB 2.6 MB/s eta 0:00:00
# Collecting scikit-image>=0.19.3
#   Downloading scikit_image-0.25.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 111.8 MB/s eta 0:00:00
# Collecting deepcell-toolbox>=0.12.1
#   Downloading DeepCell_Toolbox-0.12.1.tar.gz (39 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>=1.16.6 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from deepcell==0.12.10->-r ./requirements.txt (line 2)) (1.26.4)
# Collecting scikit-learn>=0.20.4
#   Downloading scikit_learn-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 105.8 MB/s eta 0:00:00
# Collecting pydot<2,>=1.4.2
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting deepcell-tracking~=0.6.5
#   Downloading deepcell_tracking-0.6.5.tar.gz (37 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from deepcell-toolbox>=0.12.1->deepcell==0.12.10->-r ./requirements.txt (line 2)) (2.1.4)
# Collecting networkx>=2.1
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 135.1 MB/s eta 0:00:00
# Collecting cython<3.0,>=0.28.0
#   Using cached Cython-0.29.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.7-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 37.2 MB/s eta 0:00:00
# Collecting jupyterlab
#   Downloading jupyterlab-4.4.2-py3-none-any.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 121.6 MB/s eta 0:00:00
# Collecting nbconvert
#   Downloading nbconvert-7.16.6-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.5/258.5 kB 61.0 MB/s eta 0:00:00
# Collecting jupyter-console
#   Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: ipykernel in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (6.29.5)
# Collecting notebook
#   Downloading notebook-7.4.2-py3-none-any.whl (14.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 131.4 MB/s eta 0:00:00
# Collecting pyparsing>=2.1.4
#   Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.1/111.1 kB 38.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=21 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from scikit-image>=0.19.3->deepcell==0.12.10->-r ./requirements.txt (line 2)) (24.1)
# Collecting pillow>=10.1
#   Downloading pillow-11.2.1-cp310-cp310-manylinux_2_28_x86_64.whl (4.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 165.5 MB/s eta 0:00:00
# Collecting tifffile>=2022.8.12
#   Downloading tifffile-2025.5.10-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.5/226.5 kB 59.8 MB/s eta 0:00:00
# Collecting imageio!=2.35.0,>=2.33
#   Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.8/315.8 kB 78.4 MB/s eta 0:00:00
# Collecting lazy-loader>=0.4
#   Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Collecting threadpoolctl>=3.1.0
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.5.0-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 69.6 MB/s eta 0:00:00
# Collecting spektral~=1.0.4
#   Downloading spektral-1.0.7-py3-none-any.whl (122 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.9/122.9 kB 38.9 MB/s eta 0:00:00
#   Downloading spektral-1.0.6-py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.4/114.4 kB 40.0 MB/s eta 0:00:00
# Requirement already satisfied: requests in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from spektral~=1.0.4->deepcell==0.12.10->-r ./requirements.txt (line 2)) (2.32.3)
# Collecting lxml
#   Downloading lxml-5.4.0-cp310-cp310-manylinux_2_28_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 168.5 MB/s eta 0:00:00
# Collecting flatbuffers>=1.12
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Collecting tensorboard<2.9,>=2.8
#   Downloading tensorboard-2.8.0-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 162.5 MB/s eta 0:00:00
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.17.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.8/82.8 kB 28.0 MB/s eta 0:00:00
# Collecting keras<2.9,>=2.8.0rc0
#   Downloading keras-2.8.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 116.9 MB/s eta 0:00:00
# Collecting gast>=0.2.1
#   Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 13.3 MB/s eta 0:00:00
# Collecting h5py>=2.9.0
#   Downloading h5py-3.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 154.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.6 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from tensorflow~=2.8.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (4.13.2)
# Requirement already satisfied: setuptools in /root/venv/lib/python3.10/site-packages (from tensorflow~=2.8.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (65.5.0)
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 24.8 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.9,>=2.8
#   Downloading tensorflow_estimator-2.8.0-py2.py3-none-any.whl (462 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 462.3/462.3 kB 87.4 MB/s eta 0:00:00
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 161.6 MB/s eta 0:00:00
# Collecting libclang>=9.0.1
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 78.8 MB/s eta 0:00:00
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from tensorflow~=2.8.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (1.66.1)
# Collecting absl-py>=0.4.0
#   Downloading absl_py-2.2.2-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 39.3 MB/s eta 0:00:00
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 122.6 MB/s eta 0:00:00
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting termcolor>=1.1.0
#   Downloading termcolor-3.1.0-py3-none-any.whl (7.7 kB)
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 19.8 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.12.0 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from tensorflow~=2.8.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (1.16.0)
# Collecting typeguard>=2.7
#   Downloading typeguard-4.4.2-py3-none-any.whl (35 kB)
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 143.1 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from matplotlib->deepcell==0.12.10->-r ./requirements.txt (line 2)) (2.9.0.post0)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.0/325.0 kB 75.2 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.58.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 144.1 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow~=2.8.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (0.45.1)
# Collecting markdown>=2.6.8
#   Downloading markdown-3.8-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.2/106.2 kB 26.1 MB/s eta 0:00:00
# Requirement already satisfied: google-auth<3,>=1.6.3 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from tensorboard<2.9,>=2.8->tensorflow~=2.8.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (2.34.0)
# Collecting werkzeug>=0.11.15
#   Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 55.1 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 132.1 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 102.9 MB/s eta 0:00:00
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from requests->spektral~=1.0.4->deepcell==0.12.10->-r ./requirements.txt (line 2)) (1.26.20)
# Requirement already satisfied: idna<4,>=2.5 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from requests->spektral~=1.0.4->deepcell==0.12.10->-r ./requirements.txt (line 2)) (3.8)
# Requirement already satisfied: certifi>=2017.4.17 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from requests->spektral~=1.0.4->deepcell==0.12.10->-r ./requirements.txt (line 2)) (2024.8.30)
# Requirement already satisfied: charset-normalizer<4,>=2 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from requests->spektral~=1.0.4->deepcell==0.12.10->-r ./requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (0.1.7)
# Requirement already satisfied: pyzmq>=24 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (5.14.3)
# Requirement already satisfied: debugpy>=1.6.5 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (1.8.5)
# Requirement already satisfied: nest-asyncio in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: comm>=0.1.1 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (0.2.2)
# Requirement already satisfied: ipython>=7.23.1 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (8.12.3)
# Requirement already satisfied: psutil in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (6.0.0)
# Collecting widgetsnbextension~=4.0.14
#   Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 140.5 MB/s eta 0:00:00
# Collecting jupyterlab_widgets~=3.0.15
#   Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 kB 45.8 MB/s eta 0:00:00
# Requirement already satisfied: pygments in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from jupyter-console->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (2.18.0)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from jupyter-console->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (3.0.47)
# Collecting jupyterlab-server<3,>=2.27.1
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 22.5 MB/s eta 0:00:00
# Collecting async-lru>=1.0.0
#   Downloading async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Collecting tomli>=1.2.2
#   Downloading tomli-2.2.1-py3-none-any.whl (14 kB)
# Collecting httpx>=0.25.0
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 24.1 MB/s eta 0:00:00
# Collecting jupyter-lsp>=2.0.0
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 kB 26.3 MB/s eta 0:00:00
# Requirement already satisfied: jinja2>=3.0.3 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (3.0.3)
# Collecting jupyter-server<3,>=2.4.0
#   Downloading jupyter_server-2.16.0-py3-none-any.whl (386 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.9/386.9 kB 69.0 MB/s eta 0:00:00
# Collecting notebook-shim>=0.2
#   Downloading notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Collecting pandocfilters>=1.4.1
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Requirement already satisfied: markupsafe>=2.0 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from nbconvert->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (2.1.5)
# Collecting defusedxml
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: nbformat>=5.7 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from nbconvert->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (5.10.4)
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.10.2-py3-none-any.whl (25 kB)
# Collecting bleach[css]!=5.0.0
#   Downloading bleach-6.2.0-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.4/163.4 kB 44.5 MB/s eta 0:00:00
# Collecting mistune<4,>=2.0.3
#   Downloading mistune-3.1.3-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 20.4 MB/s eta 0:00:00
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.3/187.3 kB 48.5 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from pandas->deepcell-toolbox>=0.12.1->deepcell==0.12.10->-r ./requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from pandas->deepcell-toolbox>=0.12.1->deepcell==0.12.10->-r ./requirements.txt (line 2)) (2024.1)
# Collecting webencodings
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting tinycss2<1.5,>=1.1.0
#   Downloading tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: rsa<5,>=3.1.4 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (0.4.0)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 26.0 MB/s eta 0:00:00
# Collecting anyio
#   Downloading anyio-4.9.0-py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.9/100.9 kB 33.2 MB/s eta 0:00:00
# Collecting h11>=0.16
#   Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: decorator in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (5.1.1)
# Requirement already satisfied: pexpect>4.3 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (4.9.0)
# Requirement already satisfied: pickleshare in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (0.19.2)
# Requirement already satisfied: stack-data in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (0.6.3)
# Requirement already satisfied: backcall in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: entrypoints in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (4.2.2)
# Collecting jupyter-server-terminals>=0.4.4
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Collecting overrides>=5.0
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Collecting terminado>=0.8.3
#   Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Collecting jupyter-events>=0.11.0
#   Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Collecting argon2-cffi>=21.1
#   Downloading argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Collecting prometheus-client>=0.9
#   Downloading prometheus_client-0.21.1-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 21.1 MB/s eta 0:00:00
# Collecting send2trash>=1.8.2
#   Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Collecting websocket-client>=1.7
#   Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 22.3 MB/s eta 0:00:00
# Collecting json5>=0.9.0
#   Downloading json5-0.12.0-py3-none-any.whl (36 kB)
# Collecting babel>=2.10
#   Downloading babel-2.17.0-py3-none-any.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 144.0 MB/s eta 0:00:00
# Requirement already satisfied: jsonschema>=4.18.0 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (4.23.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from nbformat>=5.7->nbconvert->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (2.20.0)
# Requirement already satisfied: wcwidth in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (0.2.13)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting exceptiongroup>=1.0.2
#   Downloading exceptiongroup-1.3.0-py3-none-any.whl (16 kB)
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.2/86.2 kB 31.2 MB/s eta 0:00:00
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (0.8.4)
# Requirement already satisfied: rpds-py>=0.7.1 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (0.20.0)
# Requirement already satisfied: attrs>=22.2.0 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (24.2.0)
# Requirement already satisfied: referencing>=0.28.4 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (0.35.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (2023.12.1)
# Collecting pyyaml>=5.3
#   Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.2/751.2 kB 112.6 MB/s eta 0:00:00
# Collecting rfc3339-validator
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting python-json-logger>=2.0.4
#   Downloading python_json_logger-3.3.0-py3-none-any.whl (15 kB)
# Collecting rfc3986-validator>=0.1.1
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow~=2.8.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (0.6.0)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 28.8 MB/s eta 0:00:00
# Requirement already satisfied: asttokens>=2.1.0 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (2.0.1)
# Requirement already satisfied: pure-eval in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (0.2.3)
# Collecting isoduration
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting uri-template
#   Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Collecting fqdn
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting jsonpointer>1.13
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting webcolors>=24.6.0
#   Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: cffi>=1.0.1 in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: pycparser in /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter<2,>=1.0.0->deepcell==0.12.10->-r ./requirements.txt (line 2)) (2.22)
# Collecting arrow>=0.15.0
#   Downloading arrow-1.3.0-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 23.9 MB/s eta 0:00:00
# Collecting types-python-dateutil>=2.8.10
#   Downloading types_python_dateutil-2.9.0.20241206-py3-none-any.whl (14 kB)
# Building wheels for collected packages: deepcell, deepcell-toolbox, deepcell-tracking
#   Building wheel for deepcell (pyproject.toml): started
#   Building wheel for deepcell (pyproject.toml): finished with status 'done'
#   Created wheel for deepcell: filename=deepcell-0.12.10-py3-none-any.whl size=243098 sha256=391a7759f2e0d2d74ff0b848efef2c63fdd89fbea5e347fca81d2d9dc615c19a
#   Stored in directory: /root/.cache/pip/wheels/b1/a9/d7/0c3c810fc9b0e52bc04f13ede1d115627c0849e1f9660c53eb
#   Building wheel for deepcell-toolbox (pyproject.toml): started
#   Building wheel for deepcell-toolbox (pyproject.toml): finished with status 'error'
#   error: subprocess-exited-with-error
#
#   × Building wheel for deepcell-toolbox (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [26 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build/lib.linux-x86_64-cpython-310/deepcell_toolbox
#       copying deepcell_toolbox/__init__.py -> build/lib.linux-x86_64-cpython-310/deepcell_toolbox
#       copying deepcell_toolbox/__version__.py -> build/lib.linux-x86_64-cpython-310/deepcell_toolbox
#       copying deepcell_toolbox/deep_watershed.py -> build/lib.linux-x86_64-cpython-310/deepcell_toolbox
#       copying deepcell_toolbox/deep_watershed_test.py -> build/lib.linux-x86_64-cpython-310/deepcell_toolbox
#       copying deepcell_toolbox/metrics.py -> build/lib.linux-x86_64-cpython-310/deepcell_toolbox
#       copying deepcell_toolbox/metrics_test.py -> build/lib.linux-x86_64-cpython-310/deepcell_toolbox
#       copying deepcell_toolbox/processing.py -> build/lib.linux-x86_64-cpython-310/deepcell_toolbox
#       copying deepcell_toolbox/processing_test.py -> build/lib.linux-x86_64-cpython-310/deepcell_toolbox
#       copying deepcell_toolbox/utils.py -> build/lib.linux-x86_64-cpython-310/deepcell_toolbox
#       copying deepcell_toolbox/utils_test.py -> build/lib.linux-x86_64-cpython-310/deepcell_toolbox
#       running build_ext
#       cythoning deepcell_toolbox/compute_overlap.pyx to deepcell_toolbox/compute_overlap.c
#       /tmp/pip-build-env-fuzia812/overlay/lib/python3.10/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /tmp/pip-install-ppa39hbn/deepcell-toolbox_4db09f76b1714bd99ec8552b66b23223/deepcell_toolbox/compute_overlap.pyx
#         tree = Parsing.p_module(s, pxd, full_module_name)
#       building 'deepcell_toolbox.compute_overlap' extension
#       creating build/temp.linux-x86_64-cpython-310/deepcell_toolbox
#       x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/root/venv/include -I/usr/include/python3.10 -I/tmp/pip-build-env-fuzia812/overlay/lib/python3.10/site-packages/numpy/_core/include -c deepcell_toolbox/compute_overlap.c -o build/temp.linux-x86_64-cpython-310/deepcell_toolbox/compute_overlap.o
#       deepcell_toolbox/compute_overlap.c:6:10: fatal error: Python.h: No such file or directory
#           6 | #include "Python.h"
#             |          ^~~~~~~~~~
#       compilation terminated.
#       error: command '/usr/bin/x86_64-linux-gnu-gcc' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for deepcell-toolbox
#   Building wheel for deepcell-tracking (setup.py): started
#   Building wheel for deepcell-tracking (setup.py): finished with status 'done'
#   Created wheel for deepcell-tracking: filename=DeepCell_Tracking-0.6.5-py3-none-any.whl size=50056 sha256=ffdddf33ef01255d06ebdaa3fe7c4bede1920664c12e186d2dd02120d4883115
#   Stored in directory: /root/.cache/pip/wheels/bf/b0/90/4b72a5cd39c67cd37800ad748881be1be7f880d3db06ea5d18
# Successfully built deepcell deepcell-tracking
# Failed to build deepcell-toolbox
# ERROR: Could not build wheels for deepcell-toolbox, which is required to install pyproject.toml-based projects
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', '# If your project has a \'requirements.txt\' file, we\'ll install it here.\nif test -f requirements.txt\n  then\n    pip install -r ./requirements.txt\n  else echo "There\'s no requirements.txt, so nothing to install."\nfi\n')
#
# File /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2478, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2476 with self.builtin_trap:
#    2477     args = (magic_arg_s, cell)
# -> 2478     result = fn(*args, **kwargs)
#    2480 # The code below prevents the output from being displayed
#    2481 # when using magics with decodator @output_can_be_silenced
#    2482 # when the last Python token in the expression is a ';'.
#    2483 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages/IPython/core/magics/script.py:153, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     151 else:
#     152     line = script
# --> 153 return self.shebang(line, cell)
#
# File /toolkit-cache/0.2.16/python3.10/kernel-libs/lib/python3.10/site-packages/IPython/core/magics/script.py:305, in ScriptMagics.shebang(self, line, cell)
#     300 if args.raise_error and p.returncode != 0:
#     301     # If we get here and p.returncode is still None, we must have
#     302     # killed it but not yet seen its return code. We don't wait for it,
#     303     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     304     rc = p.returncode or -9
# --> 305     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'# If your project has a \'requirements.txt\' file, we\'ll install it here.\nif test -f requirements.txt\n  then\n    pip install -r ./requirements.txt\n  else echo "There\'s no requirements.txt, so nothing to install."\nfi\n'' returned non-zero exit status 1.
